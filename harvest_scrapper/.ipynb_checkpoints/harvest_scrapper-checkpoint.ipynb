# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
import pandas as pd
import time
import re
from bs4 import BeautifulSoup

# %%
URL = 'https://harvest.finance/'
# page = requests.get(URL)

# initiating the webdriver. Parameter includes the path of the webdriver.
## make sure you keep chromedriver in the same path as the code
## install driver as per the chrome version
# driver = webdriver.Chrome('./chromedriver') 

driver_path = "./chromedriver"
brave_path = "/Applications/Brave Browser.app/Contents/MacOS/Brave Browser"

option = webdriver.ChromeOptions()
option.binary_location = brave_path
# option.add_argument("--incognito") OPTIONAL
# option.add_argument("--headless") OPTIONAL

# Create new Instance of Chrome
driver = webdriver.Chrome(executable_path=driver_path, options=option)

driver.get(URL) 



# this is just to ensure that the page is loaded
time.sleep(5)

# %%
## open all the harvest finance groups to get individual APYs
for i in range(13):
    driver.find_element_by_xpath('//div[@class="hv__sc-7s5idx-3 fHNtjM"]//*[name()="svg"][@data-icon="angle-down"]').click()

# %%
html = driver.page_source

# this renders the JS code and stores all
# of the information in static HTML code.
  
# Now, we could simply apply bs4 to html variable
soup = BeautifulSoup(html, "html.parser")

## Check the extracted data
print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <style type="text/css">
#    svg:not(:root).svg-inline--fa {
#   overflow: visible;
# }
#
# .svg-inline--fa {
#   display: inline-block;
#   font-size: inherit;
#   height: 1em;
#   overflow: visible;
#   vertical-align: -0.125em;
# }
# .svg-inline--fa.fa-lg {
#   vertical-align: -0.225em;
# }
# .svg-inline--fa.fa-w-1 {
#   width: 0.0625em;
# }
# .svg-inline--fa.fa-w-2 {
#   width: 0.125em;
# }
# .svg-inline--fa.fa-w-3 {
#   width: 0.1875em;
# }
# .svg-inline--fa.fa-w-4 {
#   width: 0.25em;
# }
# .svg-inline--fa.fa-w-5 {
#   width: 0.3125em;
# }
# .svg-inline--fa.fa-w-6 {
#   width: 0.375em;
# }
# .svg-inline--fa.fa-w-7 {
#   width: 0.4375em;
# }
# .svg-inline--fa.fa-w-8 {
#   width: 0.5em;
# }
# .svg-inline--fa.fa-w-9 {
#   width: 0.5625em;
# }
# .svg-inline--fa.fa-w-10 {
#   width: 0.625em;
# }
# .svg-inline--fa.fa-w-11 {
#   width: 0.6875em;
# }
# .svg-inline--fa.fa-w-12 {
#   width: 0.75em;
# }
# .svg-inline--fa.fa-w-13 {
#   width: 0.8125em;
# }
# .svg-inline--fa.fa-w-14 {
#   width: 0.875em;
# }
# .svg-inline--fa.fa-w-15 {
#   width: 0.9375em;
# }
# .svg-inline--fa.fa-w-16 {
#   width: 1em;
# }
# .svg-inline--fa.fa-w-17 {
#   width: 1.0625em;
# }
# .svg-inline--fa.fa-w-18 {
#   width: 1.125em;
# }
# .svg-inline--fa.fa-w-19 {
#   width: 1.1875em;
# }
# .svg-inline--fa.fa-w-20 {
#   width: 1.25em;
# }
# .svg-inline--fa.fa-pull-left {
#   margin-right: 0.3em;
#   width: auto;
# }
# .svg-inline--fa.fa-pull-right {
#   margin-left: 0.3em;
#   width: auto;
# }
# .svg-inline--fa.fa-border {
#   height: 1.5em;
# }
# .svg-inline--fa.fa-li {
#   width: 2em;
# }
# .svg-inline--fa.fa-fw {
#   width: 1.25em;
# }
#
# .fa-layers svg.svg-inline--fa {
#   bottom: 0;
#   left: 0;
#   margin: auto;
#   position: absolute;
#   right: 0;
#   top: 0;
# }
#
# .fa-layers {
#   display: inline-block;
#   height: 1em;
#   position: relative;
#   text-align: center;
#   vertical-align: -0.125em;
#   width: 1em;
# }
# .fa-layers svg.svg-inline--fa {
#   -webkit-transform-origin: center center;
#           transform-origin: center center;
# }
#
# .fa-layers-counter, .fa-layers-text {
#   display: inline-block;
#   position: absolute;
#   text-align: center;
# }
#
# .fa-layers-text {
#   left: 50%;
#   top: 50%;
#   -webkit-transform: translate(-50%, -50%);
#           transform: translate(-50%, -50%);
#   -webkit-transform-origin: center center;
#           transform-origin: center center;
# }
#
# .fa-layers-counter {
#   background-color: #ff253a;
#   border-radius: 1em;
#   -webkit-box-sizing: border-box;
#           box-sizing: border-box;
#   color: #fff;
#   height: 1.5em;
#   line-height: 1;
#   max-width: 5em;
#   min-width: 1.5em;
#   overflow: hidden;
#   padding: 0.25em;
#   right: 0;
#   text-overflow: ellipsis;
#   top: 0;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: top right;
#           transform-origin: top right;
# }
#
# .fa-layers-bottom-right {
#   bottom: 0;
#   right: 0;
#   top: auto;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: bottom right;
#           transform-origin: bottom right;
# }
#
# .fa-layers-bottom-left {
#   bottom: 0;
#   left: 0;
#   right: auto;
#   top: auto;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: bottom left;
#           transform-origin: bottom left;
# }
#
# .fa-layers-top-right {
#   right: 0;
#   top: 0;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: top right;
#           transform-origin: top right;
# }
#
# .fa-layers-top-left {
#   left: 0;
#   right: auto;
#   top: 0;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: top left;
#           transform-origin: top left;
# }
#
# .fa-lg {
#   font-size: 1.3333333333em;
#   line-height: 0.75em;
#   vertical-align: -0.0667em;
# }
#
# .fa-xs {
#   font-size: 0.75em;
# }
#
# .fa-sm {
#   font-size: 0.875em;
# }
#
# .fa-1x {
#   font-size: 1em;
# }
#
# .fa-2x {
#   font-size: 2em;
# }
#
# .fa-3x {
#   font-size: 3em;
# }
#
# .fa-4x {
#   font-size: 4em;
# }
#
# .fa-5x {
#   font-size: 5em;
# }
#
# .fa-6x {
#   font-size: 6em;
# }
#
# .fa-7x {
#   font-size: 7em;
# }
#
# .fa-8x {
#   font-size: 8em;
# }
#
# .fa-9x {
#   font-size: 9em;
# }
#
# .fa-10x {
#   font-size: 10em;
# }
#
# .fa-fw {
#   text-align: center;
#   width: 1.25em;
# }
#
# .fa-ul {
#   list-style-type: none;
#   margin-left: 2.5em;
#   padding-left: 0;
# }
# .fa-ul > li {
#   position: relative;
# }
#
# .fa-li {
#   left: -2em;
#   position: absolute;
#   text-align: center;
#   width: 2em;
#   line-height: inherit;
# }
#
# .fa-border {
#   border: solid 0.08em #eee;
#   border-radius: 0.1em;
#   padding: 0.2em 0.25em 0.15em;
# }
#
# .fa-pull-left {
#   float: left;
# }
#
# .fa-pull-right {
#   float: right;
# }
#
# .fa.fa-pull-left,
# .fas.fa-pull-left,
# .far.fa-pull-left,
# .fal.fa-pull-left,
# .fab.fa-pull-left {
#   margin-right: 0.3em;
# }
# .fa.fa-pull-right,
# .fas.fa-pull-right,
# .far.fa-pull-right,
# .fal.fa-pull-right,
# .fab.fa-pull-right {
#   margin-left: 0.3em;
# }
#
# .fa-spin {
#   -webkit-animation: fa-spin 2s infinite linear;
#           animation: fa-spin 2s infinite linear;
# }
#
# .fa-pulse {
#   -webkit-animation: fa-spin 1s infinite steps(8);
#           animation: fa-spin 1s infinite steps(8);
# }
#
# @-webkit-keyframes fa-spin {
#   0% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg);
#   }
#   100% {
#     -webkit-transform: rotate(360deg);
#             transform: rotate(360deg);
#   }
# }
#
# @keyframes fa-spin {
#   0% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg);
#   }
#   100% {
#     -webkit-transform: rotate(360deg);
#             transform: rotate(360deg);
#   }
# }
# .fa-rotate-90 {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=1)";
#   -webkit-transform: rotate(90deg);
#           transform: rotate(90deg);
# }
#
# .fa-rotate-180 {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=2)";
#   -webkit-transform: rotate(180deg);
#           transform: rotate(180deg);
# }
#
# .fa-rotate-270 {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=3)";
#   -webkit-transform: rotate(270deg);
#           transform: rotate(270deg);
# }
#
# .fa-flip-horizontal {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=0, mirror=1)";
#   -webkit-transform: scale(-1, 1);
#           transform: scale(-1, 1);
# }
#
# .fa-flip-vertical {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=2, mirror=1)";
#   -webkit-transform: scale(1, -1);
#           transform: scale(1, -1);
# }
#
# .fa-flip-both, .fa-flip-horizontal.fa-flip-vertical {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=2, mirror=1)";
#   -webkit-transform: scale(-1, -1);
#           transform: scale(-1, -1);
# }
#
# :root .fa-rotate-90,
# :root .fa-rotate-180,
# :root .fa-rotate-270,
# :root .fa-flip-horizontal,
# :root .fa-flip-vertical,
# :root .fa-flip-both {
#   -webkit-filter: none;
#           filter: none;
# }
#
# .fa-stack {
#   display: inline-block;
#   height: 2em;
#   position: relative;
#   width: 2.5em;
# }
#
# .fa-stack-1x,
# .fa-stack-2x {
#   bottom: 0;
#   left: 0;
#   margin: auto;
#   position: absolute;
#   right: 0;
#   top: 0;
# }
#
# .svg-inline--fa.fa-stack-1x {
#   height: 1em;
#   width: 1.25em;
# }
# .svg-inline--fa.fa-stack-2x {
#   height: 2em;
#   width: 2.5em;
# }
#
# .fa-inverse {
#   color: #fff;
# }
#
# .sr-only {
#   border: 0;
#   clip: rect(0, 0, 0, 0);
#   height: 1px;
#   margin: -1px;
#   overflow: hidden;
#   padding: 0;
#   position: absolute;
#   width: 1px;
# }
#
# .sr-only-focusable:active, .sr-only-focusable:focus {
#   clip: auto;
#   height: auto;
#   margin: 0;
#   overflow: visible;
#   position: static;
#   width: auto;
# }
#
# .svg-inline--fa .fa-primary {
#   fill: var(--fa-primary-color, currentColor);
#   opacity: 1;
#   opacity: var(--fa-primary-opacity, 1);
# }
#
# .svg-inline--fa .fa-secondary {
#   fill: var(--fa-secondary-color, currentColor);
#   opacity: 0.4;
#   opacity: var(--fa-secondary-opacity, 0.4);
# }
#
# .svg-inline--fa.fa-swap-opacity .fa-primary {
#   opacity: 0.4;
#   opacity: var(--fa-secondary-opacity, 0.4);
# }
#
# .svg-inline--fa.fa-swap-opacity .fa-secondary {
#   opacity: 1;
#   opacity: var(--fa-primary-opacity, 1);
# }
#
# .svg-inline--fa mask .fa-primary,
# .svg-inline--fa mask .fa-secondary {
#   fill: black;
# }
#
# .fad.fa-inverse {
#   color: #fff;
# }
#   </style>
#   <link href="/favicon.ico" rel="icon"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="#000000" name="theme-color"/>
#   <meta content="Your hard work is about to become easier with Harvest" name="description"/>
#   <meta content="/preview.png" property="og:image"/>
#   <meta content="/preview.png" property="twitter:image"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <script type="text/javascript">
#    if(self===top){const e=document.getElementById("antiClickjack");e.parentNode.removeChild(e)}else top.location=self.location
#   </script>
#   <title>
#    Harvest Finance
#   </title>
#   <link href="/static/css/2.0f99199d.chunk.css" rel="stylesheet"/>
#   <script async="" src="/cdn-cgi/bm/cv/669835187/api.js">
#   </script>
#   <script data-dapp-detection="">
#    !function(){let e=!1;function n(){if(!e){const n=document.createElement("meta");n.name="dapp-detected",document.head.appendChild(n),e=!0}}if(window.hasOwnProperty("ethereum")){if(window.__disableDappDetectionInsertion=!0,void 0===window.ethereum)return;n()}else{var t=window.ethereum;Object.defineProperty(window,"ethereum",{configurable:!0,enumerable:!1,set:function(e){window.__disableDappDetectionInsertion||n(),t=e},get:function(){if(!window.__disableDappDetectionInsertion){const e=arguments.callee;e&&e.caller&&e.caller.toString&&-1!==e.caller.toString().indexOf("getOwnPropertyNames")||n()}return t}})}}();
#   </script>
#   <meta name="dapp-detected"/>
#   <style data-styled="active" data-styled-version="5.2.1">
#   </style>
#   <style data-styled="active" data-styled-version="5.2.1">
#   </style>
#   <style data-react-tooltip="true">
#    .__react_component_tooltip {
#   border-radius: 3px;
#   display: inline-block;
#   font-size: 13px;
#   left: -999em;
#   opacity: 0;
#   padding: 8px 21px;
#   position: fixed;
#   pointer-events: none;
#   transition: opacity 0.3s ease-out;
#   top: -999em;
#   visibility: hidden;
#   z-index: 999;
# }
# .__react_component_tooltip.allow_hover, .__react_component_tooltip.allow_click {
#   pointer-events: auto;
# }
# .__react_component_tooltip::before, .__react_component_tooltip::after {
#   content: "";
#   width: 0;
#   height: 0;
#   position: absolute;
# }
# .__react_component_tooltip.show {
#   opacity: 0.9;
#   margin-top: 0;
#   margin-left: 0;
#   visibility: visible;
# }
# .__react_component_tooltip.place-top::before {
#   border-left: 10px solid transparent;
#   border-right: 10px solid transparent;
#   bottom: -8px;
#   left: 50%;
#   margin-left: -10px;
# }
# .__react_component_tooltip.place-bottom::before {
#   border-left: 10px solid transparent;
#   border-right: 10px solid transparent;
#   top: -8px;
#   left: 50%;
#   margin-left: -10px;
# }
# .__react_component_tooltip.place-left::before {
#   border-top: 6px solid transparent;
#   border-bottom: 6px solid transparent;
#   right: -8px;
#   top: 50%;
#   margin-top: -5px;
# }
# .__react_component_tooltip.place-right::before {
#   border-top: 6px solid transparent;
#   border-bottom: 6px solid transparent;
#   left: -8px;
#   top: 50%;
#   margin-top: -5px;
# }
# .__react_component_tooltip .multi-line {
#   display: block;
#   padding: 2px 0;
#   text-align: center;
# }
#   </style>
#  </head>
#  <body>
#   <noscript>
#    You need to enable JavaScript to run this app.
#   </noscript>
#   <div id="root">
#    <div class="hv__sc-73wv4x-0 cTaTPa">
#     <p class="hv__sc-73wv4x-1 didInH">
#      🧑‍🌾 Week 38 reward updates are live! 👩‍🌾
#      <a href="https://twitter.com/harvest_finance/status/1394723713912872965" rel="noopener noreferrer" target="_blank">
#       Details
#      </a>
#     </p>
#     <p class="hv__sc-73wv4x-1 didInH">
#      Creativity contest round 5 winners announced!
#      <a href="https://medium.com/harvest-finance/harvest-finance-creativity-contest-round-5-winners-3671ae26b99e" rel="noopener noreferrer" target="_blank">
#       Details
#      </a>
#     </p>
#    </div>
#    <div class="hv__e5gbgy-0 dzFtCB">
#     <a class="hv__e5gbgy-1 foGUZE" href="https://twitter.com/harvest_finance" target="_blank">
#      <svg aria-hidden="true" class="svg-inline--fa fa-twitter fa-w-16 fa-2x" data-icon="twitter" data-prefix="fab" focusable="false" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#       <path d="M459.37 151.716c.325 4.548.325 9.097.325 13.645 0 138.72-105.583 298.558-298.558 298.558-59.452 0-114.68-17.219-161.137-47.106 8.447.974 16.568 1.299 25.34 1.299 49.055 0 94.213-16.568 130.274-44.832-46.132-.975-84.792-31.188-98.112-72.772 6.498.974 12.995 1.624 19.818 1.624 9.421 0 18.843-1.3 27.614-3.573-48.081-9.747-84.143-51.98-84.143-102.985v-1.299c13.969 7.797 30.214 12.67 47.431 13.319-28.264-18.843-46.781-51.005-46.781-87.391 0-19.492 5.197-37.36 14.294-52.954 51.655 63.675 129.3 105.258 216.365 109.807-1.624-7.797-2.599-15.918-2.599-24.04 0-57.828 46.782-104.934 104.934-104.934 30.213 0 57.502 12.67 76.67 33.137 23.715-4.548 46.456-13.32 66.599-25.34-7.798 24.366-24.366 44.833-46.132 57.827 21.117-2.273 41.584-8.122 60.426-16.243-14.292 20.791-32.161 39.308-52.628 54.253z" fill="currentColor">
#       </path>
#      </svg>
#     </a>
#     <a class="hv__e5gbgy-1 foGUZE" href="https://discord.gg/gzWAG3Wx7Y" target="_blank">
#      <svg aria-hidden="true" class="svg-inline--fa fa-discord fa-w-14 fa-2x" data-icon="discord" data-prefix="fab" focusable="false" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#       <path d="M297.216 243.2c0 15.616-11.52 28.416-26.112 28.416-14.336 0-26.112-12.8-26.112-28.416s11.52-28.416 26.112-28.416c14.592 0 26.112 12.8 26.112 28.416zm-119.552-28.416c-14.592 0-26.112 12.8-26.112 28.416s11.776 28.416 26.112 28.416c14.592 0 26.112-12.8 26.112-28.416.256-15.616-11.52-28.416-26.112-28.416zM448 52.736V512c-64.494-56.994-43.868-38.128-118.784-107.776l13.568 47.36H52.48C23.552 451.584 0 428.032 0 398.848V52.736C0 23.552 23.552 0 52.48 0h343.04C424.448 0 448 23.552 448 52.736zm-72.96 242.688c0-82.432-36.864-149.248-36.864-149.248-36.864-27.648-71.936-26.88-71.936-26.88l-3.584 4.096c43.52 13.312 63.744 32.512 63.744 32.512-60.811-33.329-132.244-33.335-191.232-7.424-9.472 4.352-15.104 7.424-15.104 7.424s21.248-20.224 67.328-33.536l-2.56-3.072s-35.072-.768-71.936 26.88c0 0-36.864 66.816-36.864 149.248 0 0 21.504 37.12 78.08 38.912 0 0 9.472-11.52 17.152-21.248-32.512-9.728-44.8-30.208-44.8-30.208 3.766 2.636 9.976 6.053 10.496 6.4 43.21 24.198 104.588 32.126 159.744 8.96 8.96-3.328 18.944-8.192 29.44-15.104 0 0-12.8 20.992-46.336 30.464 7.68 9.728 16.896 20.736 16.896 20.736 56.576-1.792 78.336-38.912 78.336-38.912z" fill="currentColor">
#       </path>
#      </svg>
#     </a>
#     <a class="hv__e5gbgy-1 foGUZE" href="https://t.me/Breadforthepeople" target="_blank">
#      <svg aria-hidden="true" class="svg-inline--fa fa-telegram fa-w-16 fa-2x" data-icon="telegram" data-prefix="fab" focusable="false" role="img" viewbox="0 0 496 512" xmlns="http://www.w3.org/2000/svg">
#       <path d="M248 8C111 8 0 119 0 256s111 248 248 248 248-111 248-248S385 8 248 8zm121.8 169.9l-40.7 191.8c-3 13.6-11.1 16.9-22.4 10.5l-62-45.7-29.9 28.8c-3.3 3.3-6.1 6.1-12.5 6.1l4.4-63.1 114.9-103.8c5-4.4-1.1-6.9-7.7-2.5l-142 89.4-61.2-19.1c-13.3-4.2-13.6-13.3 2.8-19.7l239.1-92.2c11.1-4 20.8 2.7 17.2 19.5z" fill="currentColor">
#       </path>
#      </svg>
#     </a>
#     <a class="hv__e5gbgy-1 foGUZE" href="https://medium.com/harvest-finance" target="_blank">
#      <svg aria-hidden="true" class="svg-inline--fa fa-medium fa-w-14 fa-2x" data-icon="medium" data-prefix="fab" focusable="false" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#       <path d="M0 32v448h448V32H0zm372.2 106.1l-24 23c-2.1 1.6-3.1 4.2-2.7 6.7v169.3c-.4 2.6.6 5.2 2.7 6.7l23.5 23v5.1h-118V367l24.3-23.6c2.4-2.4 2.4-3.1 2.4-6.7V199.8l-67.6 171.6h-9.1L125 199.8v115c-.7 4.8 1 9.7 4.4 13.2l31.6 38.3v5.1H71.2v-5.1l31.6-38.3c3.4-3.5 4.9-8.4 4.1-13.2v-133c.4-3.7-1-7.3-3.8-9.8L75 138.1V133h87.3l67.4 148L289 133.1h83.2v5z" fill="currentColor">
#       </path>
#      </svg>
#     </a>
#     <a class="hv__e5gbgy-1 foGUZE" href="https://www.reddit.com/r/HarvestFinance/" target="_blank">
#      <svg aria-hidden="true" class="svg-inline--fa fa-reddit fa-w-16 fa-2x" data-icon="reddit" data-prefix="fab" focusable="false" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#       <path d="M201.5 305.5c-13.8 0-24.9-11.1-24.9-24.6 0-13.8 11.1-24.9 24.9-24.9 13.6 0 24.6 11.1 24.6 24.9 0 13.6-11.1 24.6-24.6 24.6zM504 256c0 137-111 248-248 248S8 393 8 256 119 8 256 8s248 111 248 248zm-132.3-41.2c-9.4 0-17.7 3.9-23.8 10-22.4-15.5-52.6-25.5-86.1-26.6l17.4-78.3 55.4 12.5c0 13.6 11.1 24.6 24.6 24.6 13.8 0 24.9-11.3 24.9-24.9s-11.1-24.9-24.9-24.9c-9.7 0-18 5.8-22.1 13.8l-61.2-13.6c-3-.8-6.1 1.4-6.9 4.4l-19.1 86.4c-33.2 1.4-63.1 11.3-85.5 26.8-6.1-6.4-14.7-10.2-24.1-10.2-34.9 0-46.3 46.9-14.4 62.8-1.1 5-1.7 10.2-1.7 15.5 0 52.6 59.2 95.2 132 95.2 73.1 0 132.3-42.6 132.3-95.2 0-5.3-.6-10.8-1.9-15.8 31.3-16 19.8-62.5-14.9-62.5zM302.8 331c-18.2 18.2-76.1 17.9-93.6 0-2.2-2.2-6.1-2.2-8.3 0-2.5 2.5-2.5 6.4 0 8.6 22.8 22.8 87.3 22.8 110.2 0 2.5-2.2 2.5-6.1 0-8.6-2.2-2.2-6.1-2.2-8.3 0zm7.7-75c-13.6 0-24.6 11.1-24.6 24.9 0 13.6 11.1 24.6 24.6 24.6 13.8 0 24.9-11.1 24.9-24.6 0-13.8-11-24.9-24.9-24.9z" fill="currentColor">
#       </path>
#      </svg>
#     </a>
#    </div>
#    <div class="Toastify">
#    </div>
#    <div class="hv__iyp260-11 dbGkwC">
#     <div class="hv__sc-124wt8a-0 kMVyPS">
#      <div class="hv__sc-124wt8a-4 budWLa">
#       <img alt="Harvest" src="data:image/png;base64,..."/>
#       Harvest
#      </div>
#      <div class="hv__sc-124wt8a-2 iQtIOc">
#       <div class="hv__sc-124wt8a-6 bOvrcO">
#        <span class="hv__sc-124wt8a-1 lkirPK">
#         Farm
#        </span>
#        <div class="hv__sc-124wt8a-5 jSAtcM">
#        </div>
#       </div>
#       <div class="hv__sc-124wt8a-6 bOvrcO">
#        <span class="hv__sc-124wt8a-1 cUCWSv">
#         FAQ
#        </span>
#        <div class="hv__sc-124wt8a-5 jSAtcM">
#        </div>
#       </div>
#       <div class="hv__sc-124wt8a-6 bOvrcO">
#        <span class="hv__sc-124wt8a-1 cUCWSv">
#         Dashboard
#        </span>
#        <div class="hv__sc-124wt8a-5 jSAtcM">
#        </div>
#       </div>
#       <div class="hv__sc-124wt8a-6 bOvrcO">
#        <span class="hv__sc-124wt8a-1 cUCWSv">
#         Stats
#        </span>
#        <div class="hv__sc-124wt8a-5 jSAtcM">
#        </div>
#       </div>
#       <div class="hv__sc-124wt8a-6 bOvrcO">
#        <span class="hv__sc-124wt8a-1 cUCWSv">
#         Wiki
#        </span>
#        <div class="hv__sc-124wt8a-5 jSAtcM">
#         <span class="hv__sc-124wt8a-1 cUCWSv">
#          策略
#         </span>
#        </div>
#       </div>
#       <div class="hv__sc-124wt8a-6 bOuMqD">
#        <span class="hv__sc-124wt8a-1 cUCWSv">
#         策略
#        </span>
#       </div>
#       <div class="hv__sc-124wt8a-6 bOvrcO">
#        <span class="hv__sc-124wt8a-1 cUCWSv">
#         Grain
#        </span>
#        <div class="hv__sc-124wt8a-5 jSAtcM">
#        </div>
#       </div>
#       <div class="hv__sc-124wt8a-6 bOvrcO">
#        <span class="hv__sc-124wt8a-1 cUCWSv">
#         Work
#        </span>
#        <div class="hv__sc-124wt8a-5 jSAtcM">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="hv__sc-17jj34o-0 iYjud">
#      <div class="hv__sc-17jj34o-1 fGFRgA">
#       <h1 class="hv__sc-17jj34o-8 TaFF">
#        Earn the highest rewards in DeFi with
#        <b>
#         Harvest
#        </b>
#        <img class="hv__iyp260-10 fsIqnw" height="28px" src="./icons/farm.png" width="28px"/>
#       </h1>
#       <h2 class="hv__sc-17jj34o-9 fyAIsc">
#        <i>
#         Save gas by farming with the collective.
#        </i>
#       </h2>
#       <div class="hv__iyp260-0 dNIErn" height="40px">
#       </div>
#       <div class="hv__sc-17jj34o-6 dsrMdP">
#        <div class="hv__sc-17jj34o-15 iBdcSN">
#         <h2 class="hv__sc-17jj34o-10 DsqmE">
#          Deposits in
#          <b>
#           Harvest
#          </b>
#          :
#          <br/>
#          <b>
#           <span class="hv__iyp260-7 bUkrkl">
#            <span>
#             333,991,142.52
#            </span>
#            USD
#           </span>
#          </b>
#         </h2>
#         <div class="hv__iyp260-0 bgTOVF" height="5px">
#         </div>
#         <div class="__react_component_tooltip t52131e68-c293-4494-9f18-d3c8f6467562 place-top type-dark" data-id="tooltip" id="profits-to-farmers">
#          <style>
#           .t52131e68-c293-4494-9f18-d3c8f6467562 {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.t52131e68-c293-4494-9f18-d3c8f6467562.place-top {
#         margin-top: -10px;
#     }
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-bottom {
#         margin-top: 10px;
#     }
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-left {
#         margin-left: -10px;
#     }
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-right {
#         margin-left: 10px;
#     }
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .t52131e68-c293-4494-9f18-d3c8f6467562.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#          </style>
#          <div class="hv__iyp260-9 jaxmvO">
#           <b>
#            70%
#           </b>
#           of profits goes to farmers depositing in
#           <b>
#            asset pools
#           </b>
#           <br/>
#           <b>
#            30%
#           </b>
#           goes to those farmers staking
#           <b>
#            FARM
#           </b>
#          </div>
#         </div>
#         <h2 class="hv__sc-17jj34o-10 DsqmE" currentitem="false" data-for="profits-to-farmers" data-tip="true">
#          Monthly
#          <b>
#           Profits
#          </b>
#          to Farmers:
#          <br/>
#          <b>
#           <span class="hv__iyp260-7 bUkrkl">
#            8,804,236.34 USD
#           </span>
#          </b>
#         </h2>
#        </div>
#        <div class="hv__sc-17jj34o-15 ketaQ">
#         <span>
#          Next Emissions Decrease In:
#         </span>
#         <div class="hv__sc-1ncrq8-0 fFtALU" display="block">
#          03
#          <label class="hv__sc-1ncrq8-1 gsMDOB">
#           Days
#          </label>
#          02:11:48.41
#         </div>
#         <div class="hv__iyp260-0 bgTOVF" height="5px">
#         </div>
#         <button class="hv__sc-8at94w-0 cheeec" height="40px" type="button" width="160px">
#          BUY FARM
#         </button>
#        </div>
#        <div class="__react_component_tooltip t7ac69b39-7d14-4569-954f-a428a9078022 place-top type-dark" data-id="tooltip" id="details-box">
#         <style>
#          .t7ac69b39-7d14-4569-954f-a428a9078022 {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.t7ac69b39-7d14-4569-954f-a428a9078022.place-top {
#         margin-top: -10px;
#     }
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-bottom {
#         margin-top: 10px;
#     }
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-left {
#         margin-left: -10px;
#     }
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-right {
#         margin-left: 10px;
#     }
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .t7ac69b39-7d14-4569-954f-a428a9078022.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#         </style>
#         <div class="hv__sc-17jj34o-19 hDfRqR">
#          <b>
#           FARM
#          </b>
#          stakers receive
#          <b>
#           30%
#          </b>
#          of profits generated by all other pools
#          <br/>
#          <b>
#           FARM
#          </b>
#          staking APY is a
#          <b>
#           7 day
#          </b>
#          historical average
#         </div>
#        </div>
#        <div class="hv__sc-17jj34o-15 kddbXB" currentitem="false" data-for="details-box" data-tip="">
#         <div class="hv__sc-17jj34o-18 kFxiWA">
#          <img class="hv__iyp260-10 bRdDkp" height="15px" src="./icons/farm.png" width="15px"/>
#          FARM price:
#          <b>
#           77.85 USD
#          </b>
#         </div>
#         <div class="hv__sc-17jj34o-18 kFxiWA">
#          FARM staking APY:
#          <b>
#           60.54%
#          </b>
#         </div>
#         <div class="hv__sc-17jj34o-18 kFxiWA">
#          Market cap:
#          <b>
#           52.77M USD
#          </b>
#         </div>
#         <div class="hv__sc-17jj34o-18 kFxiWA">
#          FARM staked:
#          <b>
#           67%
#          </b>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="hv__iyp260-0 bgpqeN" height="15px">
#      </div>
#      <div class="hv__sc-1gn7w7-0 bofPkk">
#       <div>
#        You are viewing
#        <b>
#         Ethereum Mainnet
#        </b>
#        farms.
#       </div>
#       <button class="hv__sc-8at94w-0 cheeec" height="40px" type="button" width="160px">
#        Connect Wallet
#       </button>
#      </div>
#      <div class="hv__iyp260-0 dumkLH" height="25px">
#      </div>
#      <div class="hv__sc-17jj34o-11 ftnwJx">
#       <button class="hv__sc-8at94w-0 eBzAA" type="button" width="240px">
#        <img class="hv__sc-17jj34o-20 kRltlf" src="data:image/png;base64,..."/>
#        Ethereum Mainnet
#        <span>
#         Farms
#        </span>
#       </button>
#       <button class="hv__sc-8at94w-0 fTAYyr" type="button" width="240px">
#        <img class="hv__sc-17jj34o-20 kRltlf" src="data:image/png;base64,..."/>
#        Binance Smart Chain
#        <span>
#         Farms
#        </span>
#        <div class="hv__iyp260-13 kIIDqM">
#        </div>
#       </button>
#      </div>
#      <div class="hv__iyp260-0 etfRsn" height="20px">
#      </div>
#      <div class="hv__o2fyls-0 drmfa-D">
#       <div class="scrollable-on-mobile">
#        <span class="scrollable-on-mobile__trigger is-open">
#        </span>
#        <div class="scrollable-on-mobile__contentOuter" style="height: auto; transition: none 0s ease 0s; overflow: inherit;">
#         <div class="scrollable-on-mobile__contentInner">
#          <div class="hv__o2fyls-1 gIpQim">
#           <div class="hv__o2fyls-2 fXKpOF">
#            <div class="hv__o2fyls-3 fWTqVz" width="215px">
#             Asset
#            </div>
#            <div class="hv__o2fyls-3 bwMCpy">
#             Harvest APY
#            </div>
#            <div class="hv__o2fyls-3 bwMCpy" currentitem="false" data-for="total-deposits-column-header" data-tip="true">
#             Deposits ($)
#            </div>
#            <div class="__react_component_tooltip t8d4b5f4c-1304-45c3-884e-101c7c52b2c4 place-top type-dark" data-id="tooltip" id="total-deposits-column-header">
#             <style>
#              .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4 {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-top {
#         margin-top: -10px;
#     }
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-bottom {
#         margin-top: 10px;
#     }
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-left {
#         margin-left: -10px;
#     }
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-right {
#         margin-left: 10px;
#     }
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .t8d4b5f4c-1304-45c3-884e-101c7c52b2c4.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#             </style>
#             Refreshes hourly
#            </div>
#            <div class="hv__o2fyls-3 kRiRKQ" width="130px">
#             Your balance
#            </div>
#           </div>
#           <div>
#            <div class="__react_component_tooltip t0cc7dc90-9ab4-4a88-a8b6-b25e28256555 place-top type-dark allow_click" data-id="tooltip" id="vault-panel-tooltop-0">
#             <style>
#              .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555 {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-top {
#         margin-top: -10px;
#     }
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-bottom {
#         margin-top: 10px;
#     }
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-left {
#         margin-left: -10px;
#     }
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-right {
#         margin-left: 10px;
#     }
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .t0cc7dc90-9ab4-4a88-a8b6-b25e28256555.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#             </style>
#            </div>
#            <div class="hv__sc-1qly185-0 haIOQE" currentitem="false" data-for="vault-panel-tooltop-0" data-tip="true">
#             <div class="Collapsible">
#              <span class="Collapsible__trigger is-closed">
#               <div class="hv__sc-10fnk7c-0 dNLCEJ">
#                <div>
#                 <div class="hv__sc-10fnk7c-4 jRqRUQ" data-for="token-info-WETH" data-tip="" width="235px">
#                  <svg aria-hidden="true" class="svg-inline--fa fa-angle-down fa-w-10 fa-lg" data-icon="angle-down" data-prefix="fas" focusable="false" role="img" viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg">
#                   <path d="M143 352.3L7 216.3c-9.4-9.4-9.4-24.6 0-33.9l22.6-22.6c9.4-9.4 24.6-9.4 33.9 0l96.4 96.4 96.4-96.4c9.4-9.4 24.6-9.4 33.9 0l22.6 22.6c9.4 9.4 9.4 24.6 0 33.9l-136 136c-9.2 9.4-24.4 9.4-33.8 0z" fill="currentColor">
#                   </path>
#                  </svg>
#                  <img alt="WETH" class="hv__sc-10fnk7c-1 gPFZgY" src="./icons/eth.png"/>
#                  WETH
#                 </div>
#                </div>
#                <div class="hv__sc-10fnk7c-3 estMBD" width="80px">
#                 <div class="__react_component_tooltip t9085d829-ce39-4ebb-b8ad-c35687e7b4f1 place-top type-dark allow_click" data-id="tooltip" id="WETH">
#                  <style>
#                   .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1 {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-top {
#         margin-top: -10px;
#     }
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-bottom {
#         margin-top: 10px;
#     }
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-left {
#         margin-left: -10px;
#     }
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-right {
#         margin-left: 10px;
#     }
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .t9085d829-ce39-4ebb-b8ad-c35687e7b4f1.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#                  </style>
#                  <div align="left" style="font-weight: 500;">
#                   <b>
#                    0.29%
#                   </b>
#                   : Auto harvested
#                   <b>
#                    COMP
#                   </b>
#                   <br/>
#                   <b>
#                    5.66%
#                   </b>
#                   :
#                   <b>
#                    FARM
#                   </b>
#                   rewards
#                   <br/>
#                  </div>
#                 </div>
#                 <div class="hv__sc-10fnk7c-2 dWQbUr" currentitem="false" data-for="WETH" data-tip="">
#                  <b>
#                   5.95%
#                  </b>
#                  <img class="hv__iyp260-10 hsHxXd" src="./icons/comp.png"/>
#                  <img class="hv__iyp260-10 hsHxXd" src="./icons/farm.png"/>
#                 </div>
#                </div>
#                <div class="__react_component_tooltip t85088ef8-55ff-48ec-88c4-ff1a6aa269bf place-top type-dark" data-id="tooltip" id="deposit-details-WETH">
#                 <style>
#                  .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-top {
#         margin-top: -10px;
#     }
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-bottom {
#         margin-top: 10px;
#     }
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-left {
#         margin-left: -10px;
#     }
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-right {
#         margin-left: 10px;
#     }
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .t85088ef8-55ff-48ec-88c4-ff1a6aa269bf.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#                 </style>
#                 Updates hourly
#                </div>
#                <div class="hv__sc-10fnk7c-3 bliSFv" currentitem="false" data-for="deposit-details-WETH" data-tip="" width="167px">
#                 10.01M
#                </div>
#                <div class="hv__sc-10fnk7c-3 dblqaB">
#                 <div class="__react_component_tooltip t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d place-top type-dark" data-id="tooltip" id="balance-details-WETH">
#                  <style>
#                   .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-top {
#         margin-top: -10px;
#     }
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-bottom {
#         margin-top: 10px;
#     }
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-left {
#         margin-left: -10px;
#     }
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-right {
#         margin-left: 10px;
#     }
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .t69df7a3b-fd3c-4df7-9cc7-e3667b1b4d6d.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#                  </style>
#                  Your combined 0.000000000 FARM + 0.000000000 (in iFARM)
#                 </div>
#                 <span class="hv__iyp260-7 bUkrkl" currentitem="false" data-for="balance-details-WETH" data-tip="">
#                  <b>
#                   0.000000000
#                  </b>
#                 </span>
#                </div>
#               </div>
#              </span>
#              <div class="Collapsible__contentOuter" style="height: 0px; transition: height 200ms linear 0s; overflow: hidden;">
#               <div class="Collapsible__contentInner">
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="__react_component_tooltip t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c place-top type-dark allow_click" data-id="tooltip" id="vault-panel-tooltop-1">
#             <style>
#              .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-top {
#         margin-top: -10px;
#     }
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-bottom {
#         margin-top: 10px;
#     }
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-left {
#         margin-left: -10px;
#     }
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-right {
#         margin-left: 10px;
#     }
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .t9cd3aa45-3d3e-4596-9d49-2a65308b0f5c.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#             </style>
#            </div>
#            <div class="hv__sc-1qly185-0 haIOQE" currentitem="false" data-for="vault-panel-tooltop-1" data-tip="true">
#             <div class="Collapsible">
#              <span class="Collapsible__trigger is-closed">
#               <div class="hv__sc-10fnk7c-0 dNLCEJ">
#                <div>
#                 <img class="hv__sc-10fnk7c-6 fquCOD" src="data:image/png;base64,..."/>
#                 <div class="hv__sc-10fnk7c-4 jRqRUQ" data-for="token-info-complifi_COMPFI_WETH" data-tip="" width="235px">
#                  <svg aria-hidden="true" class="svg-inline--fa fa-angle-down fa-w-10 fa-lg" data-icon="angle-down" data-prefix="fas" focusable="false" role="img" viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg">
# ...
#         border-left-width: 6px;
#     }
#
#     .t5677bc29-8936-44fc-8c0a-141a7318f84c.place-right {
#         margin-left: 10px;
#     }
#     .t5677bc29-8936-44fc-8c0a-141a7318f84c.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .t5677bc29-8936-44fc-8c0a-141a7318f84c.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#                  </style>
#                  <div align="left" style="font-weight: 500;">
#                  </div>
#                 </div>
#                 <div class="hv__sc-10fnk7c-2 dWQbUr" currentitem="false" data-for="UNI" data-tip="">
#                  Inactive
#                 </div>
#                </div>
#                <div class="__react_component_tooltip tb256ab98-0840-4365-8ca1-a9d1572bbfd7 place-top type-dark" data-id="tooltip" id="deposit-details-UNI">
#                 <style>
#                  .tb256ab98-0840-4365-8ca1-a9d1572bbfd7 {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-top {
#         margin-top: -10px;
#     }
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-bottom {
#         margin-top: 10px;
#     }
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-left {
#         margin-left: -10px;
#     }
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-right {
#         margin-left: 10px;
#     }
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .tb256ab98-0840-4365-8ca1-a9d1572bbfd7.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#                 </style>
#                 Updates hourly
#                </div>
#                <div class="hv__sc-10fnk7c-3 bliSFv" currentitem="false" data-for="deposit-details-UNI" data-tip="" width="167px">
#                 49.12K
#                </div>
#                <div class="hv__sc-10fnk7c-3 dblqaB">
#                 <div class="__react_component_tooltip tb94b1e76-2c6a-4a0f-9584-8a65dac73037 place-top type-dark" data-id="tooltip" id="balance-details-UNI">
#                  <style>
#                   .tb94b1e76-2c6a-4a0f-9584-8a65dac73037 {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
#   	}
#
#   	.tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-top {
#         margin-top: -10px;
#     }
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-top::before {
#         border-top: 8px solid transparent;
#     }
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-top::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-top-color: #222;
#         border-top-style: solid;
#         border-top-width: 6px;
#     }
#
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-bottom {
#         margin-top: 10px;
#     }
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-bottom::before {
#         border-bottom: 8px solid transparent;
#     }
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-bottom::after {
#         border-left: 8px solid transparent;
#         border-right: 8px solid transparent;
#         top: -6px;
#         left: 50%;
#         margin-left: -8px;
#         border-bottom-color: #222;
#         border-bottom-style: solid;
#         border-bottom-width: 6px;
#     }
#
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-left {
#         margin-left: -10px;
#     }
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-left::before {
#         border-left: 8px solid transparent;
#     }
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-left::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         right: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-left-color: #222;
#         border-left-style: solid;
#         border-left-width: 6px;
#     }
#
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-right {
#         margin-left: 10px;
#     }
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-right::before {
#         border-right: 8px solid transparent;
#     }
#     .tb94b1e76-2c6a-4a0f-9584-8a65dac73037.place-right::after {
#         border-top: 5px solid transparent;
#         border-bottom: 5px solid transparent;
#         left: -6px;
#         top: 50%;
#         margin-top: -4px;
#         border-right-color: #222;
#         border-right-style: solid;
#         border-right-width: 6px;
#     }
#                  </style>
#                  Your combined 0.000000000 FARM + 0.000000000 (in iFARM)
#                 </div>
#                 <span class="hv__iyp260-7 bUkrkl" currentitem="false" data-for="balance-details-UNI" data-tip="">
#                  <b>
#                   0.000000000
#                  </b>
#                 </span>
#                </div>
#               </div>
#              </span>
#              <div class="Collapsible__contentOuter" style="height: 0px; transition: height 200ms linear 0s; overflow: hidden;">
#               <div class="Collapsible__contentInner">
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="hv__iyp260-0 bgpqeN" height="15px">
#      </div>
#      <div class="hv__sc-17jj34o-13 NhbyH">
#      </div>
#      <h2 class="hv__sc-17jj34o-10 DsqmE">
#       <span class="hv__iyp260-7 bUkrkl">
#        <b>
#         $
#         <span>
#          107,581,001.08
#         </span>
#        </b>
#       </span>
#       in gas fees saved.
#      </h2>
#      <div class="hv__iyp260-0 bgTOVF" height="5px">
#      </div>
#      <h2 class="hv__sc-17jj34o-10 DsqmE">
#       <span class="hv__iyp260-7 bUkrkl">
#        <b>
#         $
#         <span>
#          333,991,142.52
#         </span>
#        </b>
#       </span>
#       of deposits are auto harvesting yields.
#      </h2>
#      <div class="hv__iyp260-0 etfRsn" height="20px">
#      </div>
#      <div class="hv__sc-17jj34o-2 gPXVOr">
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="COMP" class="hv__sc-17jj34o-12 IHnKk" src="./icons/comp.png"/>
#        COMP
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="COMFI" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/comfi.png"/>
#        COMFI
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="IDLE" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/idle.png"/>
#        IDLE
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="INDEX" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/index.png"/>
#        INDEX
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="SUSHI" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/sushi.png"/>
#        SUSHI
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="CRV" class="hv__sc-17jj34o-12 IHnKk" src="./icons/curve.png"/>
#        CRV
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="BOR" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/bor.png"/>
#        BOR
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="BASv2" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/basv2.png"/>
#        BASv2
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="1INCH" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/1inch.png"/>
#        1INCH
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="SNX" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/snx.png"/>
#        SNX
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="MIR" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/mir.png"/>
#        MIR
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="LDO" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/ldo.png"/>
#        LDO
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="MUSE" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/muse.png"/>
#        MUSE
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="CAKE" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/cake.png"/>
#        CAKE
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="XVS" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/xvs.png"/>
#        XVS
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="EGG" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/egg.png"/>
#        EGG
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="EPS" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/eps.png"/>
#        EPS
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="BELT" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/belt.png"/>
#        BELT
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="SPACE" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/space.png"/>
#        SPACE
#       </div>
#       <div class="hv__sc-17jj34o-5 ciZHvY">
#        <img alt="ICE" class="hv__sc-17jj34o-12 guxdPJ" src="./icons/ice.png"/>
#        ICE
#       </div>
#      </div>
#      <div class="hv__iyp260-0 dNIErn" height="40px">
#      </div>
#      <div class="hv__sc-17jj34o-3 YlTci">
#       <h2 class="hv__sc-17jj34o-10 DsqmE">
#        <b>
#         Audited by:
#        </b>
#       </h2>
#       <div class="hv__sc-17jj34o-4 iaNJix">
#        <img alt="certik" class="hv__sc-17jj34o-12 XcLke" height="auto" src="/static/media/least-authority.df5ad335.png" width="150"/>
#        <img alt="pecksheild" class="hv__sc-17jj34o-12 XcLke" height="auto" src="data:image/png;base64,..." width="150"/>
#        <img alt="haechi" class="hv__sc-17jj34o-12 XcLke" height="auto" src="data:image/png;base64,..." width="150"/>
#        <img alt="certik" class="hv__sc-17jj34o-12 XcLke" height="auto" src="data:image/png;base64,..." width="150"/>
#       </div>
#      </div>
#     </div>
#     <div class="hv__sc-1wb03iv-0 bTNRBP">
#     </div>
#     <a class="hv__iyp260-15 lepijC" href="/work">
#     </a>
#    </div>
#   </div>
#   <script>
#    !function(e){function r(r){for(var n,i,l=r[0],a=r[1],f=r[2],c=0,s=[];c<l.length;c++)i=l[c],Object.prototype.hasOwnProperty.call(o,i)&&o[i]&&s.push(o[i][0]),o[i]=0;for(n in a)Object.prototype.hasOwnProperty.call(a,n)&&(e[n]=a[n]);for(p&&p(r);s.length;)s.shift()();return u.push.apply(u,f||[]),t()}function t(){for(var e,r=0;r<u.length;r++){for(var t=u[r],n=!0,l=1;l<t.length;l++){var a=t[l];0!==o[a]&&(n=!1)}n&&(u.splice(r--,1),e=i(i.s=t[0]))}return e}var n={},o={1:0},u=[];function i(r){if(n[r])return n[r].exports;var t=n[r]={i:r,l:!1,exports:{}};return e[r].call(t.exports,t,t.exports,i),t.l=!0,t.exports}i.m=e,i.c=n,i.d=function(e,r,t){i.o(e,r)||Object.defineProperty(e,r,{enumerable:!0,get:t})},i.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},i.t=function(e,r){if(1&r&&(e=i(e)),8&r)return e;if(4&r&&"object"==typeof e&&e&&e.__esModule)return e;var t=Object.create(null);if(i.r(t),Object.defineProperty(t,"default",{enumerable:!0,value:e}),2&r&&"string"!=typeof e)for(var n in e)i.d(t,n,function(r){return e[r]}.bind(null,n));return t},i.n=function(e){var r=e&&e.__esModule?function(){return e.default}:function(){return e};return i.d(r,"a",r),r},i.o=function(e,r){return Object.prototype.hasOwnProperty.call(e,r)},i.p="/";var l=this["webpackJsonpharvest-ui"]=this["webpackJsonpharvest-ui"]||[],a=l.push.bind(l);l.push=r,l=l.slice();for(var f=0;f<l.length;f++)r(l[f]);var p=a;t()}([])
#   </script>
#   <script src="/static/js/2.c00d85ad.chunk.js">
#   </script>
#   <script src="/static/js/main.b37cad3f.chunk.js">
#   </script>
#   <div id="WEB3_CONNECT_MODAL_ID">
#    <div class="sc-kEjbxe dpFxXj web3modal-modal-lightbox" offset="0" opacity="0.4">
#     <div class="sc-iqHYGH epxNjl web3modal-modal-container">
#      <div class="sc-crrsfI iDhzRL web3modal-modal-hitbox">
#      </div>
#      <div class="sc-dQppl gDCVVR web3modal-modal-card">
#       <div class="sc-jrAGrp dXWCyY">
#        <span>
#         1. Choose Network
#        </span>
#        <div class="sc-bqyKva iJKBPv">
#         <div class="sc-gKsewC lgYMll web3modal-chain-wrapper active">
#          <div class="sc-jSgupP eklyWs web3modal-chain-container">
#           <img alt="Ethereum" class="sc-iBPRYJ cOWINi" src="data:image/png;base64,..."/>
#           <div class="sc-fubCfw gpDVAW">
#            Ethereum
#           </div>
#          </div>
#         </div>
#         <div class="sc-gKsewC kCkXhL web3modal-chain-wrapper">
#          <div class="sc-jSgupP eklyWs web3modal-chain-container">
#           <img alt="Binance Smart Chain" class="sc-iBPRYJ cOWINi" src="data:image/png;base64,..."/>
#           <div class="sc-fubCfw gpDVAW">
#            Binance Smart Chain
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="sc-jrAGrp dXWCyY">
#        <span>
#         2. Choose Wallet
#        </span>
#        <div class="sc-bqyKva iJKBPv">
#         <div class="sc-eCssSg bFmbZG web3modal-provider-wrapper">
#          <div class="sc-hKgILt fYEJHQ web3modal-provider-container">
#           <div class="sc-bdfBwQ cIKpxU web3modal-provider-icon">
#            <img alt="WalletConnect" src="data:image/svg+xml;base64,..."/>
#           </div>
#           <div class="sc-gsTCUz jlPfwF web3modal-provider-name">
#            WalletConnect
#           </div>
#           <div class="sc-dlfnbm dJkPWN web3modal-provider-description">
#            Scan with WalletConnect to connect
#           </div>
#          </div>
#         </div>
#         <div class="sc-eCssSg fsqgYl web3modal-provider-wrapper" disabled="">
#          <div class="sc-hKgILt fYEJHQ web3modal-provider-container">
#           <div class="sc-bdfBwQ cIKpxU web3modal-provider-icon">
#            <img alt="Binance Chain Wallet" src="data:image/png;base64,..."/>
#           </div>
#           <div class="sc-gsTCUz jlPfwF web3modal-provider-name">
#            Binance Chain Wallet
#           </div>
#           <div class="sc-dlfnbm dJkPWN web3modal-provider-description">
#            Connect to your Binance Chain Wallet
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'65378770bfc341dd',m:'751b978b40c02a55ed9082356daa7ef612ca189f-1621702075-1800-AUvTeQELMo/VYGKDJKIOVtlFKTne98Po+Wz5zBMaELosBKSZjuTsG0ZKmf2XBPDJpS4APu5vX5Q8Oz9S/a+X/CavVvzk1QMfm2QTfgLLh6HTSUdmIYKEul0RhSm3Xrf9Nw==',s:[0x29268539a6,0x91eb8e57f2],}})();
#   </script>
#  </body>
# </html>

# %%
## Extract vault ids for all harvest vaults
all_ids = soup.findAll('div', id=re.compile('^vault-'))

## get all the vault ids
vault_ids = []
for vault_id in all_ids:
    vault_ids.append(vault_id.get('id'))

## check all the vault ids
print(vault_ids)
# Out:
# ['vault-panel-tooltop-0', 'vault-panel-tooltop-1', 'vault-panel-tooltop-profit-sharing-farm', 'vault-Stablecoins', 'vault-panel-tooltop-2', 'vault-panel-tooltop-3', 'vault-panel-tooltop-5', 'vault-panel-tooltop-16', 'vault-panel-tooltop-18', 'vault-panel-tooltop-19', 'vault-panel-tooltop-21', 'vault-panel-tooltop-22', 'vault-panel-tooltop-23', 'vault-panel-tooltop-48', 'vault-panel-tooltop-49', 'vault-panel-tooltop-50', 'vault-panel-tooltop-67', 'vault-BTC', 'vault-panel-tooltop-15', 'vault-panel-tooltop-17', 'vault-panel-tooltop-20', 'vault-panel-tooltop-24', 'vault-panel-tooltop-25', 'vault-ETH 2.0', 'vault-panel-tooltop-57', 'vault-Uniswap Liquidity', 'vault-panel-tooltop-7', 'vault-panel-tooltop-59', 'vault-panel-tooltop-60', 'vault-panel-tooltop-75', 'vault-panel-tooltop-76', 'vault-panel-tooltop-FARM_WETH_LP', 'vault-panel-tooltop-FARM_GRAIN_LP', 'vault-Sushiswap', 'vault-panel-tooltop-8', 'vault-panel-tooltop-9', 'vault-panel-tooltop-10', 'vault-panel-tooltop-11', 'vault-panel-tooltop-12', 'vault-panel-tooltop-13', 'vault-panel-tooltop-14', 'vault-Sushi HODL', 'vault-panel-tooltop-62', 'vault-panel-tooltop-63', 'vault-panel-tooltop-64', 'vault-panel-tooltop-65', 'vault-panel-tooltop-66', 'vault-1INCH', 'vault-panel-tooltop-40', 'vault-panel-tooltop-41', 'vault-panel-tooltop-42', 'vault-1INCH (old)', 'vault-panel-tooltop-36', 'vault-panel-tooltop-37', 'vault-panel-tooltop-38', 'vault-panel-tooltop-39', 'vault-NFT', 'vault-panel-tooltop-68', 'vault-panel-tooltop-69', 'vault-panel-tooltop-70', 'vault-panel-tooltop-71', 'vault-panel-tooltop-72', 'vault-panel-tooltop-73', 'vault-panel-tooltop-74', 'vault-mSTONKs', 'vault-panel-tooltop-51', 'vault-panel-tooltop-52', 'vault-panel-tooltop-53', 'vault-panel-tooltop-54', 'vault-panel-tooltop-55', 'vault-panel-tooltop-56', 'vault-LINK', 'vault-panel-tooltop-61', 'vault-Seigniorage', 'vault-panel-tooltop-27', 'vault-panel-tooltop-28', 'vault-Inactive', 'vault-panel-tooltop-4', 'vault-panel-tooltop-6', 'vault-panel-tooltop-26', 'vault-panel-tooltop-29', 'vault-panel-tooltop-30', 'vault-panel-tooltop-31', 'vault-panel-tooltop-32', 'vault-panel-tooltop-33', 'vault-panel-tooltop-34', 'vault-panel-tooltop-35', 'vault-panel-tooltop-43', 'vault-panel-tooltop-44', 'vault-panel-tooltop-45', 'vault-panel-tooltop-46', 'vault-panel-tooltop-47', 'vault-panel-tooltop-UNI']

# %%
import os

if os.path.isfile('harvest_vaults_data.csv'):
    harvest_data = pd.read_csv('harvest_vaults_data.csv', index_col=0)
else:
    harvest_data = pd.DataFrame(columns = ['vault_name', 'vault_apy', 'vault_total_assets'], index=pd.to_datetime([]))

# %%
## extract data from all the harvest vaults

for vault_id in vault_ids:

    ## extract the vault data
    results = soup.find_all("div", {"data-for": vault_id})

    ## check all the extracted data
#     print(len(results), results[0])
    
    ## extract vault information using div class "hv__sc-10fnk7c-4 jRqRUQ"
    results_value = results[0].find_all("div", {"class": "hv__sc-10fnk7c-4 jRqRUQ"})
    token_name = None
    for result in results_value:
        token_name = result['data-for'].replace('token-info-', '').strip()
        token = result.text.split('Chad embodies')[0] ## cleaning the token name with Chad embodies
        print(token, result['data-for'])
    
    if not token_name:
        continue
    
    results_value = results[0].find_all("div", {"data-for": token_name})
    for result in results_value:
        vault_apy = result.text
        print(result.text)
        
    results_value = results[0].find_all("div", {"data-for": "deposit-details-" + token_name})
    for result in results_value:
        vault_total_assets = result.text
        print(result.text)
    
    ## storing data in pandas dataframe, timezone is in UTC
    harvest_data.loc[pd.to_datetime("now"), :] = (token, vault_apy, vault_total_assets)
# Out:
#  WETH token-info-WETH
# 5.95%
# 10.01M
#  COMFI-ETH token-info-complifi_COMPFI_WETH
# 10000%+
# 330.90K
#  FARM token-info-FARM
# 60.54%
# 26.38M
#  USDC token-info-USDC
# 10.47%
# 19.25M
#  USDT token-info-USDT
# 10.05%
# 9.76M
#  DAI token-info-DAI
# 10.38%
# 22.16M
#  CRV:HUSD token-info-crvHUSD
# 7.61%
# 1.73M
#  YCRV token-info-YCRV
# 13.52%
# 1.42M
#  3CRV token-info-ThreePool
# 5.02%
# 8.10M
#  CRV:COMPOUND token-info-crvCOMPOUND
# 9.28%
# 1.53M
#  CRV:BUSD token-info-crvBUSD
# 17.22%
# 2.25M
#  CRV:USDN token-info-crvUSDN
# 26.38%
# 2.82M
#  CRV:EURS token-info-crvEURS
# 23.94%
# 607.15K
#  CRV:GUSD token-info-crvGUSD
# 11.46%
# 180.90K
#  CRV:UST token-info-crvUST
# 12.01%
# 245.86K
#  CRV:USDP token-info-crvUSDP
# 24.70%
# 147.96K
#  CRV:HBTC token-info-crvHBTC
# 4.57%
# 8.77M
#  CRV:OBTC token-info-crvOBTC
# 12.38%
# 6.43M
#  CRV:TBTC token-info-TBTCMixed
# 3.70%
# 464.95K
#  CRV:RENWBTC token-info-CRVRENWBTC
# 4.24%
# 41.44M
#  WBTC token-info-WBTC
# 3.21%
# 744.00K
#  CRV:STETH token-info-crvSTETH
# 8.34%
# 39.78M
#  ETH-DPI token-info-ETH-DPI
# 22.47%
# 2.76M
#  WBTC-KBTC token-info-KLONDIKE_WBTC_KBTC
# 72.06%
# 86.61K
#  WBTC-KLONX token-info-KLONDIKE_WBTC_KLON
# 76.20%
# 23.40K
#  ETH-MVI token-info-ETH-MVI
# 17.98%
# 667.16K
#  KXUSD-DAI token-info-KLONDIKE_KXUSD_DAI
# 96.99%
# 87.52K
#  FARM/ETH token-info-FARM_WETH_LP
# 37.65%
# 7.01M
#  FARM/GRAIN token-info-FARM_GRAIN_LP
# 57.39%
# 82.09K
#  ETH-SUSHI token-info-SUSHI-SUSHI-ETH
# 41.02%
# 284.53K
#  ETH-PERP token-info-SUSHI-ETH-PERP
# 87.99%
# 57.63K
#  ETH-DAI token-info-SUSHI-ETH-DAI
# 93.35%
# 15.51M
#  ETH-USDC token-info-SUSHI-ETH-USDC
# 130.07%
# 13.38M
#  ETH-USDT token-info-SUSHI-ETH-USDT
# 110.73%
# 31.20M
#  ETH-WBTC token-info-SUSHI-ETH-WBTC
# 27.76%
# 12.49M
#  ETH-UST token-info-SUSHI-ETH-UST
# 73.76%
# 272.75K
#  SUSHI token-info-SUSHI_HODL
# 32.48%
# 3.62M
#  ETH-DAI token-info-SUSHI-ETH-DAI-HODL
# 131.20%
# 15.20M
#  ETH-USDC token-info-SUSHI-ETH-USDC-HODL
# 166.58%
# 6.84M
#  ETH-USDT token-info-SUSHI-ETH-USDT-HODL
# 148.66%
# 5.03M
#  ETH-WBTC token-info-SUSHI-ETH-WBTC-HODL
# 63.74%
# 9.67M
#  1INCH-ETH token-info-1INCH-ETH-1INCH
# 9.80%
# 586.75K
#  1INCH-USDC token-info-1INCH-USDC-1INCH
# 19.10%
# 289.85K
#  1INCH-WBTC token-info-1INCH-WBTC-1INCH
# 5.20%
# 273.60K
#  ETH-DAI token-info-1INCH-ETH-DAI
# 131.20%
# 154.05K
#  ETH-USDC token-info-1INCH-ETH-USDC
# 166.58%
# 109.55K
#  ETH-USDT token-info-1INCH-ETH-USDT
# 148.66%
# 70.52K
#  ETH-WBTC token-info-1INCH-ETH-WBTC
# 63.74%
# 8.03M
#  MUSE-ETH token-info-MUSE-ETH
# 168.62%
# 378.92K
#  DUDES20-ETH token-info-DUDES20-ETH
# 368.75%
# 69.43K
#  MASK20-ETH token-info-MASK20-ETH
# 217.37%
# 63.97K
#  ROPE20-ETH token-info-ROPE20-ETH
# 3531.76%
# 39.58K
#  MCAT20-ETH token-info-MOONCAT20-ETH
# 266.40%
# 32.81K
#  MEME20-ETH token-info-MEME20-ETH
# 375.26%
# 57.86K
#  GPUNKS20-ETH token-info-GPUNKS20-ETH
# 343.39%
# 39.71K
#  MAAPL-UST token-info-mirrorAAPL
# 48.53%
# 360.03K
#  MAMZN-UST token-info-mirrorAMZN
# 54.68%
# 228.21K
#  MGOOGL-UST token-info-mirrorGOOG
# 59.70%
# 177.93K
#  MTSLA-UST token-info-mirrorTSLA
# 51.95%
# 234.68K
#  MNFLX-UST token-info-mirrorNFLX
# 42.24%
# 522.19K
#  MTWTR-UST token-info-mirrorTWTR
# 46.43%
# 504.83K
#  CRV:LINK token-info-crvLink
# 6.60%
# 1.35M
#  DAI-BAC token-info-BAC-DAI
# 48.14%
# 681.89K
#  DAI-BASv2 token-info-DAI-BAS
# 92.84%
# 53.30K
#  TUSD token-info-TUSD
# Inactive
# 24.13K
#  CRV:AAVE token-info-crvAAVE
# Inactive
# 169.94
#  RENBTC token-info-RENBTC
# Inactive
# 95.20K
#  MIC-USDT token-info-MIC-USDT
# Inactive
# 275.53K
#  MIS-USDT token-info-MIS-USDT
# Inactive
# 53.18K
#  WBTC-TBTC token-info-SUSHI-WBTC-TBTC
# Inactive
# 778.83
#  ETH-DAI token-info-ETH-DAI
# Inactive
# 16.70K
#  ETH-USDC token-info-ETH-USDC
# Inactive
# 29.40K
#  ETH-USDT token-info-ETH-USDT
# Inactive
# 9.43K
#  ETH-WBTC token-info-ETH-WBTC
# Inactive
# 24.58K
#  DAI-BSG token-info-DAI-BSG
# Inactive
# 1.66K
#  DAI-BSGS token-info-DAI-BSGS
# Inactive
# 3.06K
#  BAC token-info-BAC
# Inactive
# 258.43
#  ESD token-info-ESD
# Inactive
# 13.49K
#  DSD token-info-DSD
# Inactive
# 1.81K
#  FARM/USDC token-info-UNI
# Inactive
# 49.12K

# %%
harvest_data.tail()
# Out:
#                             vault_name  vault_apy vault_total_assets
# 2021-05-22 16:48:14.936549    DAI-BSGS  Inactive               3.06K
# 2021-05-22 16:48:14.957231         BAC  Inactive              258.43
# 2021-05-22 16:48:14.979378         ESD  Inactive              13.49K
# 2021-05-22 16:48:14.999375         DSD  Inactive               1.81K
# 2021-05-22 16:48:15.025793   FARM/USDC   Inactive             49.12K

# %%
harvest_data.head()
# Out:
#                                vault_name  vault_apy vault_total_assets
# 2021-04-19 18:16:07.770006           WETH    6.97%               14.12M
# 2021-04-19 18:16:07.834631     MEME20-ETH  582.15%              138.36K
# 2021-04-19 18:16:07.919914   GPUNKS20-ETH  718.01%               68.43K
# 2021-04-19 18:16:07.969280        ETH-MVI   34.46%              874.25K
# 2021-04-19 18:16:08.006898      KXUSD-DAI  265.00%              285.16K

# %%
harvest_data.isna().sum()
# Out:
# vault_name            0
# vault_apy             0
# vault_total_assets    0
# dtype: int64

# %%
harvest_data.to_csv('harvest_vaults_data.csv')

# %%
harvest_data.shape
# Out:
# (2533, 3)

# %% [markdown]
# ### Not required to run ------------------------------------------------------------------------------------------

# %%
## extract the data when all the svg tabs are closed, not required if tabs are open

# for vault_id in vault_ids:

#     ## extract the vault data
#     results = soup.find_all("div", {"data-for": vault_id})

#     ## check all the extracted data
# #     print(len(results), results[0])
    
# #     break

#     ## extract vault information using div class "hv__sc-10fnk7c-4 jRqRUQ"
#     results_value = results[0].find_all("div", {"class": "hv__sc-7s5idx-1 dJXGHv"})
#     for result in results_value:
#         print(result.text)
    
#     results_value = results[0].find_all("div", {"class": "hv__sc-7s5idx-5 EvSIe"})
#     for result in results_value:
#         print(result.text)
        
#     results_value = results[0].find_all("div", {"class": "hv__sc-7s5idx-1 kyOfvw"})
#     for result in results_value:
#         print(result.text)
    
#     print ("-------------")
# #     ## storing data in pandas dataframe, timezone is in UTC
# #     yearn_data.loc[pd.to_datetime("now"), :] = (vault_name, vault_type, vault_apy, vault_total_assets)
# Out:
# -------------
# -------------
# -------------
# -------------
# -------------
# -------------
# Stablecoins
# USDC
# USDT
# DAI
# CRV:HUSD
# YCRV
# 3CRV
# CRV:COMPOUND
# CRV:BUSD
# CRV:USDN
# CRV:EURS
# CRV:GUSD
# CRV:UST
# CRV:USDP
# APY: 14.95% - 46.67%Deposits($): 103.57MRewards:
# -------------
# Sushi HODL
# SUSHI
# ETH-DAI
# ETH-USDC
# ETH-USDT
# ETH-WBTC
# APY: 17.24% - 67.86%Deposits($): 31.51MRewards:
# -------------
# ETH 2.0
# CRV:STETH
# APY: 11.65%Deposits($): 37.10MRewards:
# -------------
# BTC
# CRV:HBTC
# CRV:OBTC
# CRV:TBTC
# CRV:RENWBTC
# WBTC
# APY: 1.6% - 13.75%Deposits($): 130.92MRewards:
# -------------
# NFT
# MUSE-ETH
# DUDES20-ETH
# MASK20-ETH
# ROPE20-ETH
# MCAT20-ETH
# APY: 278.82% - 508.4%Deposits($): 1.40MRewards:
# -------------
# 1INCH
# 1INCH-ETH
# 1INCH-USDC
# 1INCH-WBTC
# APY: 75.22% - 118.99%Deposits($): 3.59MRewards:
# -------------
# 1INCH (old)Migrated to Sushi HODL
# ETH-DAI
# ETH-USDC
# ETH-USDT
# ETH-WBTC
# APY: 28.21% - 67.86%Deposits($): 10.59MRewards:
# -------------
# Sushiswap
# ETH-SUSHI
# ETH-DAI
# ETH-USDC
# ETH-USDT
# ETH-WBTC
# ETH-UST
# APY: 14.02% - 83.39%Deposits($): 68.04MRewards:
# -------------
# Uniswap Liquidity
# ETH-DPI
# WBTC-KBTC
# WBTC-KLONX
# FARM/ETH
# FARM/GRAIN
# APY: 26.86% - 172.57%Deposits($): 22.16MRewards:
# -------------
# Seigniorage
# DAI-BAC
# DAI-BASv2
# DAI-BSG
# DAI-BSGS
# APY: 16.66% - 188.85%Deposits($): 1.63MRewards:
# -------------
# mSTONKs
# MAAPL-UST
# MAMZN-UST
# MGOOGL-UST
# MTSLA-UST
# MNFLX-UST
# MTWTR-UST
# APY: 73.05% - 127%Deposits($): 2.33MRewards:
# -------------
# -------------
# -------------
# -------------
# -------------
# -------------
# -------------
# LINK
# CRV:LINK
# APY: 21.42%Deposits($): 2.26MRewards:
# -------------
# Inactive
# TUSD
# CRV:AAVE
# RENBTC
# MIC-USDT
# MIS-USDT
# WBTC-TBTC
# ETH-DAI
# ETH-USDC
# ETH-USDT
# ETH-WBTC
# BAC
# ESD
# DSD
# FARM/USDC
# APY: InactiveDeposits($): 812.41KRewards:None
# -------------
